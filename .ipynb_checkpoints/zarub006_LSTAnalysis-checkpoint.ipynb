# %% [markdown]
# # Analysis of Land Surface Temperature (LST) across Varying Urban Land Covers in Minneapolis, Minnesota
#
# There are three main goals of this project.
# 1. To determine and quantify the relationships between land cover and land surface temperature (LST), a key variable that will allow for an examination of the Urban Heat Island (UHI) effect at a fine-scale across the City of Minneapolis.
# 2. To specifically examine the role that parks and green spaces play in combatting UHI effects in the study area.
# 3. To use the information generated from goals two and three to identify locations where UHI effects are significant and propose mitigation efforts to aid in lowering the UHI effects of these "hot-spots"
#
# The following diagram contains a brief overview of the intended workflow for the project.
#
# ![LST%20Analysis%20and%20Park%20Suitability%20Workflow.png](attachment:LST%20Analysis%20and%20Park%20Suitability%20Workflow.png)

# %% [markdown]
# ## 1. Data Processing and Exploration
#
# In the following code blocks, the data will be downloaded, processed, and briefly explored. All necessary Python modules will also be imported.

# %%
# Importing Modules
import pandas as pd
import numpy as np
import rasterio as rio
import geopandas as gpd
import folium as flm
import ipyleaflet as ipl

# %% [markdown]
# ### LST Rasters

# %%
# Read in LST Rasters

# Clip Rasters to Study Area (eliminate as much unnecessary data as possible to speed up processing time)

# Convert Rasters to Arrays

# Find Average Values of Cells

# Write Average Values to New Output Raster

# %%
# Map the Average LST Raster

# %% [markdown]
# ### Land Cover

# %%
# Read in LC Dataset (VECTOR OR RASTER???)

# Vectorize LC (ONLY IF INPUT IS RASTER)

# Clip to Study Area (IF NECESSARY)

# %%
# Map the LC Data

# %% [markdown]
# ### Parks

# %%
# Read in Parks Dataset

# Create Buffers (100', 250', 500', 750', Greater than 750')

# NEED TO MAKE SURE NO OVERLAP IN BUFFERS

# Union of Buffers and Study Area

# Set Null Values (Areas not within any buffer) to a standard Value (i.e., 9999)

# %%
# Map the Parks & the Buffers

# %% [markdown]
# ## 2. Zonal Statistics
# In the following code blocks, LST zonal statistics will be calculated for the different land cover and park buffer features. Zonal statistics are summary statistics calculated over a given area. For example, in this case we are calculating the average LST value of all of the cells that fall within a specific land cover feature or park buffer feature.
